# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from scipy import stats
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels

# %%
import urllib
params ='DRIVER={SQL Server};SERVER=CL-AMILAH\AMILA;DATABASE=GSH;UID=Amila;Trusted_Connection=yes;'       
params = urllib.parse.quote_plus(params)

from sqlalchemy import create_engine
db = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
sql = '''
SELECT inv.[ID] ,inv.SiteUID, [Date] , [OutletUID] ,ot.Name AS outlet ,pr.Description AS province , di.Description AS district 
, ar.Description AS Area , inv.[AgentUID] ,Concat(emp.FirstName ,' ' , emp.MiddleInitials , ' ', emp.LastName ) AS AgentName , inv.[DistributorUID] , d.Name AS distributor, [ItemUID] ,it.Description AS item, [UnitQty] 
, [UnitPrice] , [RetailUnitPrice] , [FreeQty] , [FreeCompanyQty] , [GrossValue]
,datename(YEAR, Date) AS Year
,datename(month, Date) AS MonthName
,MONTH(Date) AS Month
,datename(DAY, Date) AS Day
,DATEPART(DW,Date) AS WeekDay
,datename(WEEKDAY, Date) AS DateName
,DATEPART (hh,Date) as Hour

  FROM [GSH].[dbo].[vw_Invoice] inv
  LEFT JOIN [GSH].[dbo].[vw_InvoiceLine] invl
  ON inv.siteUID = invl.TxnInvoice_SiteUID AND inv.uid = invl.TxnInvoiceUID	
  LEFT JOIN [GSH].[dbo].[Item] it
  ON invl.ItemUID = it.UID
  LEFT JOIN [GSH].[dbo].[Outlet] ot
  ON inv.OutletUID = ot.UID
  LEFT JOIN [GSH].[dbo].[Area] pr
  ON ot.ProvinceUID = pr.UID
  LEFT JOIN [GSH].[dbo].[Area] di
  ON ot.DistrictUID = di.UID
  LEFT JOIN [GSH].[dbo].[Area] ar
  ON ot.AreaUID = ar.UID
  LEFT JOIN [GSH].[dbo].[Distributor] d
  ON inv.DistributorUID = d.UID
  LEFT JOIN [GSH].[dbo].[avLogin] avlg
  ON inv.AgentUID = avlg.BusinessUserUID
  LEFT JOIN [GSH].[dbo].[Employee] emp
  ON avlg.EmployeeUID = emp.UID
  WHERE inv.mpt_TypeEnum IN ( 21 , 44, 14, 1) AND inv.ExpiryDate IS NULL AND inv.SubmittedDate IS NOT NULL
  AND Date >= '2018-11-01' AND Date <= '2020-03-01' ;
'''

invoice_All = pd.read_sql_query(sql, db)

# %%
#disply all the columns
pd.set_option('display.max_columns', None)

# %%
invoice_All.head()
# Out:
#              ID  SiteUID                    Date  OutletUID  \
# 0  CSO011801117       55 2018-11-02 07:56:14.343        283
# 1  CSO009101064      113 2018-11-02 10:52:04.427       3557
# 2  CSO009101064      113 2018-11-02 10:52:04.427       3557
# 3  IN0066000101        0 2018-11-02 08:59:44.727       2639
# 4  CSO008001483       56 2018-11-02 15:58:07.127        289
#
#                 outlet            province district      Area  AgentUID  \
# 0     SUPREME PHARMACY    Western Province  Gampaha   Negombo       118
# 1  Wimalasiri Pharmacy  Southern Province     Galle  Batapola        91
# 2  Wimalasiri Pharmacy  Southern Province     Galle  Batapola        91
# 3       Aruna Pharmacy  Southern Province    Matara    Matara       155
# 4  SILVER RAY PHARMACY    Western Province  Gampaha   Negombo        80
#
#                   AgentName  DistributorUID  \
# 0                                         2
# 1            Sasanga  Nawod               8
# 2            Sasanga  Nawod               8
# 3  Priyashantha  Niyagamage              14
# 4             Sithum  Asela               2
#
#                           distributor  ItemUID  \
# 0  The West Central Pharma (Pvt) Ltd.      341
# 1                    Kalyani Pharmacy       56
# 2                    Kalyani Pharmacy       56
# 3              Unichemist Distributor      125
# 4  The West Central Pharma (Pvt) Ltd.      189
#
#                                       item  UnitQty  UnitPrice  \
# 0  Major-II Blood Glucose Test Strips-25's      2.0    1010.00
# 1                 GLUCOTRUST 500mg (10X10)     10.0     175.44
# 2                 GLUCOTRUST 500mg (10X10)      0.0     175.44
# 3                        Fusiway H-15g-1's      3.0     282.70
# 4                   Fastaid Gel 1.16% 20 g     10.0      67.60
#
#    RetailUnitPrice  FreeQty  FreeCompanyQty  GrossValue  Year MonthName  \
# 0           1160.0      0.0             0.0      2020.0  2018  November
# 1            200.0      0.0             0.0      1754.4  2018  November
# 2            200.0      1.0             1.0         0.0  2018  November
# 3            325.0      0.0             0.0       848.1  2018  November
# 4             77.0      0.0             0.0       676.0  2018  November
#
#    Month Day  WeekDay DateName  Hour
# 0     11   2        6   Friday     7
# 1     11   2        6   Friday    10
# 2     11   2        6   Friday    10
# 3     11   2        6   Friday     8
# 4     11   2        6   Friday    15

# %% [markdown]
# ### Select the most selling product to identify the time series prediction

# %%
# select product sales records 
#Belcid Suspension 240ml top 1 product
Pro1_invoice_All = invoice_All.loc[invoice_All['ItemUID'] == 43]

# %%
Pro1_invoice_All.head()
# Out:
#                 ID  SiteUID                    Date  OutletUID  \
# 1240  IN0066000103        0 2018-11-02 12:05:39.753       2693
# 1262  CSO009101074      113 2018-11-03 11:11:12.093       1561
# 1263  CSO009101074      113 2018-11-03 11:11:12.093       1561
# 1982  CSO009101068      113 2018-11-02 16:46:55.527       1712
# 1983  CSO009101068      113 2018-11-02 16:46:55.527       1712
#
#                  outlet            province    district               Area  \
# 1240  Sethsuwa Pharmacy  Southern Province   Hambantota  Angunukolapelessa
# 1262  Tharushi Pharmacy    Western Province    Kalutara        Bandaragama
# 1263  Tharushi Pharmacy    Western Province    Kalutara        Bandaragama
# 1982   Saranga Pharmacy  Southern Province        Galle          Hikkaduwa
# 1983   Saranga Pharmacy  Southern Province        Galle          Hikkaduwa
#
#       AgentUID                 AgentName  DistributorUID  \
# 1240       155  Priyashantha  Niyagamage              14
# 1262        91            Sasanga  Nawod               8
# 1263        91            Sasanga  Nawod               8
# 1982        91            Sasanga  Nawod               8
# 1983        91            Sasanga  Nawod               8
#
#                  distributor  ItemUID                  item  UnitQty  \
# 1240  Unichemist Distributor       43  Losatrust 50mg 100's      3.0
# 1262        Kalyani Pharmacy       43  Losatrust 50mg 100's     50.0
# 1263        Kalyani Pharmacy       43  Losatrust 50mg 100's      0.0
# 1982        Kalyani Pharmacy       43  Losatrust 50mg 100's     50.0
# 1983        Kalyani Pharmacy       43  Losatrust 50mg 100's      0.0
#
#       UnitPrice  RetailUnitPrice  FreeQty  FreeCompanyQty  GrossValue  Year  \
# 1240      276.3            315.0      0.0             0.0       828.9  2018
# 1262      276.3            315.0      0.0             0.0     13815.0  2018
# 1263      276.3            315.0     10.0            10.0         0.0  2018
# 1982      276.3            315.0      0.0             0.0     13815.0  2018
# 1983      276.3            315.0     10.0            10.0         0.0  2018
#
#      MonthName  Month Day  WeekDay  DateName  Hour
# 1240  November     11   2        6    Friday    12
# 1262  November     11   3        7  Saturday    11
# 1263  November     11   3        7  Saturday    11
# 1982  November     11   2        6    Friday    16
# 1983  November     11   2        6    Friday    16

# %%
 #get date from date time
Pro1_invoice_All['just_date'] = Pro1_invoice_All['Date'].dt.date
# Out:
# <ipython-input-8-dd577f3fd3f2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Pro1_invoice_All['just_date'] = Pro1_invoice_All['Date'].dt.date

# %%
Pro1_inv_grp = Pro1_invoice_All.groupby("just_date").agg({'GrossValue':'sum'}).reset_index()

# %%
Pro1_inv_grp
# Out:
#       just_date  GrossValue
# 0    2018-11-01     11052.0
# 1    2018-11-02     75429.9
# 2    2018-11-03    474130.8
# 3    2018-11-05     92007.9
# 4    2018-11-06    227947.5
# ..          ...         ...
# 416  2020-02-25    351499.0
# 417  2020-02-26    335849.0
# 418  2020-02-27    317695.0
# 419  2020-02-28    332719.0
# 420  2020-02-29   1040099.0
#
# [421 rows x 2 columns]

# %%
plt.scatter(Pro1_inv_grp.just_date , Pro1_inv_grp.GrossValue , alpha=0.3,cmap='viridis')
plt.xlabel("Date")
plt.ylabel("$ sales")
plt.title("$ sales ")
plt.rcParams['figure.figsize'] = [15, 5]
plt.show()

# %%
Pro1_inv_grp.plot(kind = 'line', x = 'just_date', y = 'GrossValue')
plt.show()

# %%
# remove z score > 3 
Pro1_inv_grp = Pro1_inv_grp[(np.abs(stats.zscore(Pro1_inv_grp["GrossValue"])) < 3)]

# %%
plt.scatter(Pro1_inv_grp.just_date , Pro1_inv_grp.GrossValue , alpha=0.3,cmap='viridis')
plt.xlabel("Date")
plt.ylabel("$ sales")
plt.title("$ sales ")
plt.rcParams['figure.figsize'] = [15, 5]
plt.show()

# %%
Pro1_inv_grp.plot(kind = 'line', x = 'just_date', y = 'GrossValue')
plt.show()

# %%
 #fill in the missing dates
drange = pd.date_range(start=Pro1_inv_grp.just_date.min(), end=Pro1_inv_grp.just_date.max())
Pro1_inv_grp = Pro1_inv_grp.set_index('just_date').reindex(drange).rename_axis('just_date').reset_index()

# %%
#fill missing value with mean
Pro1_inv_grp.fillna({"GrossValue":Pro1_inv_grp['GrossValue'].mean().round(1)}, inplace=True)

# %%
Pro1_inv_grp = Pro1_inv_grp.sort_index()
Pro1_inv_grp.head(50)
# Out:
#     just_date  GrossValue
# 0  2018-11-01    11052.00
# 1  2018-11-02    75429.90
# 2  2018-11-03   474130.80
# 3  2018-11-04   241395.80
# 4  2018-11-05    92007.90
# 5  2018-11-06   227947.50
# 6  2018-11-07    45036.90
# 7  2018-11-08   101125.80
# 8  2018-11-09   134834.40
# 9  2018-11-10   139807.80
# 10 2018-11-11   241395.80
# 11 2018-11-12    96705.00
# 12 2018-11-13   226842.30
# 13 2018-11-14   170477.10
# 14 2018-11-15   136768.50
# 15 2018-11-16    75877.60
# 16 2018-11-17    49734.00
# 17 2018-11-18   241395.80
# 18 2018-11-19    62167.50
# 19 2018-11-20    11052.00
# 20 2018-11-21   318850.20
# 21 2018-11-22   241395.80
# 22 2018-11-23    33485.05
# 23 2018-11-24     6631.20
# 24 2018-11-25   241395.80
# 25 2018-11-26    46418.40
# 26 2018-11-27   611728.20
# 27 2018-11-28    12302.00
# 28 2018-11-29    56365.20
# 29 2018-11-30   241395.80
# 30 2018-12-01    23485.50
# 31 2018-12-02   241395.80
# 32 2018-12-03   261656.10
# 33 2018-12-04    85100.40
# 34 2018-12-05   189818.10
# 35 2018-12-06   224355.60
# 36 2018-12-07    48905.10
# 37 2018-12-08    34537.50
# 38 2018-12-09   241395.80
# 39 2018-12-10    87034.50
# 40 2018-12-11    96152.40
# 41 2018-12-12    83995.20
# 42 2018-12-13    14091.30
# 43 2018-12-14   366373.80
# 44 2018-12-15    58299.30
# 45 2018-12-16   241395.80
# 46 2018-12-17    27630.00
# 47 2018-12-18   109414.80
# 48 2018-12-19    26524.80
# 49 2018-12-20    47799.90

# %%
#Pro1_inv_Nor_Sm = Pro1_inv_Nor_Sm.reset_index()
train = Pro1_inv_grp.loc[Pro1_inv_grp['just_date'] <= "2019-11-30"]
train = train.set_index('just_date')
test = Pro1_inv_grp.loc[Pro1_inv_grp['just_date'] > "2019-11-30"]
test = test.set_index('just_date')

# %%
from pmdarima import auto_arima
model = auto_arima(train.GrossValue, test='adf', trace=True)
results = model.fit(train.GrossValue)
results.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=10724.542, Time=0.17 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=10783.311, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=10724.590, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=10742.314, Time=0.04 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=11104.531, Time=0.01 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=10723.511, Time=0.06 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=10726.747, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=10723.197, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=10723.086, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=10721.098, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=10723.067, Time=0.06 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=10725.065, Time=0.12 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=10776.308, Time=0.03 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[0] intercept
# Total fit time: 0.704 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  395
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -5356.549
# Date:                Thu, 17 Mar 2022   AIC                          10721.098
# Time:                        19:14:45   BIC                          10737.013
# Sample:                             0   HQIC                         10727.403
#                                 - 395
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    1.26e+05   1.68e+04      7.486      0.000     9.3e+04    1.59e+05
# ar.L1          0.3374      0.042      8.026      0.000       0.255       0.420
# ar.L2          0.1184      0.039      3.067      0.002       0.043       0.194
# sigma2      3.523e+10      0.073   4.81e+11      0.000    3.52e+10    3.52e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               287.13
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.29   Skew:                             1.40
# Prob(H) (two-sided):                  0.15   Kurtosis:                         6.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.27e+26. Standard errors may be unstable.
# """

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model = SARIMAX(train['GrossValue'],
                order=(2,0,0),seasonal_order=(0,0,0,0))
results = model.fit(disp=0)
results.summary()
# Out:
# c:\users\amila.h\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# c:\users\amila.h\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\base\tsa_model.py:536: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             GrossValue   No. Observations:                  395
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -5385.154
# Date:                Thu, 17 Mar 2022   AIC                          10776.308
# Time:                        19:14:45   BIC                          10788.244
# Sample:                    11-01-2018   HQIC                         10781.037
#                          - 11-30-2019
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5177      0.040     12.992      0.000       0.440       0.596
# ar.L2          0.2984      0.039      7.724      0.000       0.223       0.374
# sigma2      4.076e+10   4.89e-14   8.34e+23      0.000    4.08e+10    4.08e+10
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.08   Jarque-Bera (JB):               160.22
# Prob(Q):                              0.08   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.27   Skew:                             0.87
# Prob(H) (two-sided):                  0.17   Kurtosis:                         5.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 7.46e+39. Standard errors may be unstable.
# """

# %%
results.plot_diagnostics()
plt.show()

# %% [markdown]
# ### Rolling Forecast ARIMA Model

# %%
X = Pro1_inv_grp.GrossValue.values
data_Size = int(len(Pro1_inv_grp.GrossValue.values))
train_size = int(len(train.GrossValue.values))


train, test = X[0:train_size], X[train_size:data_Size]
history = [x for x in train]
predictions = []

# %%
for t in range(len(test)):
    model = SARIMAX(history, order=(2,0,0),seasonal_order=(0,0,0,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# predicted=615922.718016, expected=241395.800000
# predicted=445832.276962, expected=151179.000000
# predicted=148031.923638, expected=302045.000000
# predicted=198111.467507, expected=202824.000000
# predicted=192469.104290, expected=661995.000000
# predicted=396663.360507, expected=134590.000000
# predicted=268771.477441, expected=103603.000000
# predicted=92381.942678, expected=63226.000000
# predicted=62793.250499, expected=352751.000000
# predicted=196292.546037, expected=266989.000000
# predicted=240133.411710, expected=241395.800000
# predicted=201566.570902, expected=538986.000000
# predicted=344722.149332, expected=353377.000000
# predicted=340669.339499, expected=434077.000000
# predicted=325964.184812, expected=7825.000000
# predicted=134924.707522, expected=378104.000000
# predicted=190580.740306, expected=370905.000000
# predicted=301167.656460, expected=201885.000000
# predicted=213935.165441, expected=142415.000000
# predicted=132598.930432, expected=154935.000000
# predicted=120846.048121, expected=139911.000000
# predicted=117131.881143, expected=3130.000000
# predicted=43991.250165, expected=376852.000000
# predicted=189061.928804, expected=253843.000000
# predicted=241866.315105, expected=241395.800000
# predicted=198154.038647, expected=106733.000000
# predicted=126850.932227, expected=217848.000000
# predicted=141455.683318, expected=247896.000000
# predicted=190513.152961, expected=25040.000000
# predicted=88004.708090, expected=163386.000000
# predicted=89215.572368, expected=926426.000000
# predicted=517592.603496, expected=241395.800000
# predicted=405004.780607, expected=109550.000000
# predicted=126573.184452, expected=278516.000000
# predicted=171968.118434, expected=318008.000000
# predicted=242422.436604, expected=29109.000000
# predicted=109081.864997, expected=562148.000000
# predicted=287530.236493, expected=295159.000000
# predicted=317170.721996, expected=413473.000000
# predicted=295017.786092, expected=250400.000000
# predicted=250258.574211, expected=4069.000000
# predicted=77799.349413, expected=150240.000000
# predicted=75595.121887, expected=241395.800000
# predicted=165242.224935, expected=325833.000000
# predicted=235027.061181, expected=321764.000000
# predicted=258768.270921, expected=50080.000000
# predicted=121923.068277, expected=416603.000000
# predicted=221254.498215, expected=166516.000000
# predicted=209773.708583, expected=220352.000000
# predicted=159731.185199, expected=241395.800000
# predicted=186717.506473, expected=400327.000000
# predicted=272092.006929, expected=254156.000000
# predicted=248569.488739, expected=333658.000000
# predicted=243169.141124, expected=458232.000000
# predicted=329987.250425, expected=359011.000000
# predicted=319295.150972, expected=104229.000000
# predicted=161553.632672, expected=241395.800000
# predicted=151551.556485, expected=217535.000000
# predicted=181929.434432, expected=184044.000000
# predicted=158007.293444, expected=352125.000000
# predicted=231285.419470, expected=703311.000000
# predicted=460113.242663, expected=827259.000000
# predicted=634273.397170, expected=241395.800000
# predicted=370749.428790, expected=241395.800000
# predicted=193726.241262, expected=252904.000000
# predicted=199631.526324, expected=241395.800000
# predicted=197309.322569, expected=174967.000000
# predicted=160279.142227, expected=273562.000000
# predicted=190437.674746, expected=216909.000000
# predicted=191250.541027, expected=34430.000000
# predicted=81911.833283, expected=241395.800000
# predicted=132071.188981, expected=472004.000000
# predicted=311341.951797, expected=436635.000000
# predicted=362257.485808, expected=333658.000000
# predicted=299174.305557, expected=839779.000000
# predicted=528546.021138, expected=253143.600000
# predicted=382624.071789, expected=224108.000000
# predicted=188972.294355, expected=241395.800000
# predicted=189080.598144, expected=555262.000000
# predicted=353707.986528, expected=295472.000000
# predicted=316405.795556, expected=320825.000000
# predicted=251062.966708, expected=416290.000000
# predicted=307417.200941, expected=282013.000000
# predicted=268162.724174, expected=137407.000000
# predicted=154192.023522, expected=241395.800000
# predicted=163445.827970, expected=217848.000000
# predicted=182878.227392, expected=351499.000000
# predicted=243692.844193, expected=335849.000000
# predicted=276266.447496, expected=317695.000000
# predicted=262457.454241, expected=332719.000000
# predicted=264789.664090, expected=1040099.000000

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %f' % rmse)
# Out:
# RMSE: 229048.834020

# %% [markdown]
# #### Since this is quiet high value for RMSE the model is not best to predict.

# %%
plt.plot(test)
plt.plot(predictions)
plt.legend(['test', 'predicted'])
